# %% [markdown]
# ## Lectura de datos

# %%
# !ls

# %%
# from google.colab import files
# files.upload()

# %%
import pandas as pd
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
# Carga conjunto de datos
datos = pd.read_csv("AED_diabetes.csv", header=None, names=col_names)
datos.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %%
feature_cols = ['pregnant', 'glucose', 'bp' ,'skin','insulin', 'bmi','pedigree','age']
X = datos[feature_cols] # Predictores
y = datos.label # Outcome

# %%
X.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age
# 0         6      148  72    35        0  33.6     0.627   50
# 1         1       85  66    29        0  26.6     0.351   31
# 2         8      183  64     0        0  23.3     0.672   32
# 3         1       89  66    23       94  28.1     0.167   21
# 4         0      137  40    35      168  43.1     2.288   33

# %%
import pandas as pd
import numpy as np

#X = datos.iloc[:,1:8]

corr = X.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d38fa_row0_col0, #T_d38fa_row1_col1, #T_d38fa_row2_col2, #T_d38fa_row3_col3, #T_d38fa_row4_col4, #T_d38fa_row5_col5, #T_d38fa_row6_col6, #T_d38fa_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d38fa_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_d38fa_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_d38fa_row0_col3, #T_d38fa_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_d38fa_row0_col4, #T_d38fa_row0_col5, #T_d38fa_row0_col6, #T_d38fa_row3_col0, #T_d38fa_row3_col1, #T_d38fa_row3_col7, #T_d38fa_row6_col2, #T_d38fa_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d38fa_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_d38fa_row1_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_d38fa_row1_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_d38fa_row1_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_d38fa_row1_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_d38fa_row1_col5, #T_d38fa_row3_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_d38fa_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_d38fa_row1_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_d38fa_row2_col0, #T_d38fa_row7_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_d38fa_row2_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_d38fa_row2_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_d38fa_row2_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_d38fa_row2_col5, #T_d38fa_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_d38fa_row2_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_d38fa_row2_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_d38fa_row3_col2, #T_d38fa_row5_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_d38fa_row3_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_d38fa_row3_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_d38fa_row4_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d38fa_row4_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_d38fa_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_d38fa_row4_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_d38fa_row4_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_d38fa_row4_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_d38fa_row4_col7, #T_d38fa_row7_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_d38fa_row5_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_d38fa_row5_col2, #T_d38fa_row5_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_d38fa_row5_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_d38fa_row5_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d38fa_row5_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_d38fa_row6_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_d38fa_row6_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d38fa_row6_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_d38fa_row6_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d38fa_row6_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_d38fa_row7_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_d38fa_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_d38fa_row7_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d38fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d38fa_level0_col0" class="col_heading level0 col0" >pregnant</th>
#       <th id="T_d38fa_level0_col1" class="col_heading level0 col1" >glucose</th>
#       <th id="T_d38fa_level0_col2" class="col_heading level0 col2" >bp</th>
#       <th id="T_d38fa_level0_col3" class="col_heading level0 col3" >skin</th>
#       <th id="T_d38fa_level0_col4" class="col_heading level0 col4" >insulin</th>
#       <th id="T_d38fa_level0_col5" class="col_heading level0 col5" >bmi</th>
#       <th id="T_d38fa_level0_col6" class="col_heading level0 col6" >pedigree</th>
#       <th id="T_d38fa_level0_col7" class="col_heading level0 col7" >age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d38fa_level0_row0" class="row_heading level0 row0" >pregnant</th>
#       <td id="T_d38fa_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d38fa_row0_col1" class="data row0 col1" >0.129459</td>
#       <td id="T_d38fa_row0_col2" class="data row0 col2" >0.141282</td>
#       <td id="T_d38fa_row0_col3" class="data row0 col3" >-0.081672</td>
#       <td id="T_d38fa_row0_col4" class="data row0 col4" >-0.073535</td>
#       <td id="T_d38fa_row0_col5" class="data row0 col5" >0.017683</td>
#       <td id="T_d38fa_row0_col6" class="data row0 col6" >-0.033523</td>
#       <td id="T_d38fa_row0_col7" class="data row0 col7" >0.544341</td>
#     </tr>
#     <tr>
#       <th id="T_d38fa_level0_row1" class="row_heading level0 row1" >glucose</th>
#       <td id="T_d38fa_row1_col0" class="data row1 col0" >0.129459</td>
#       <td id="T_d38fa_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d38fa_row1_col2" class="data row1 col2" >0.152590</td>
#       <td id="T_d38fa_row1_col3" class="data row1 col3" >0.057328</td>
#       <td id="T_d38fa_row1_col4" class="data row1 col4" >0.331357</td>
#       <td id="T_d38fa_row1_col5" class="data row1 col5" >0.221071</td>
#       <td id="T_d38fa_row1_col6" class="data row1 col6" >0.137337</td>
#       <td id="T_d38fa_row1_col7" class="data row1 col7" >0.263514</td>
#     </tr>
#     <tr>
#       <th id="T_d38fa_level0_row2" class="row_heading level0 row2" >bp</th>
#       <td id="T_d38fa_row2_col0" class="data row2 col0" >0.141282</td>
#       <td id="T_d38fa_row2_col1" class="data row2 col1" >0.152590</td>
#       <td id="T_d38fa_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d38fa_row2_col3" class="data row2 col3" >0.207371</td>
#       <td id="T_d38fa_row2_col4" class="data row2 col4" >0.088933</td>
#       <td id="T_d38fa_row2_col5" class="data row2 col5" >0.281805</td>
#       <td id="T_d38fa_row2_col6" class="data row2 col6" >0.041265</td>
#       <td id="T_d38fa_row2_col7" class="data row2 col7" >0.239528</td>
#     </tr>
#     <tr>
#       <th id="T_d38fa_level0_row3" class="row_heading level0 row3" >skin</th>
#       <td id="T_d38fa_row3_col0" class="data row3 col0" >-0.081672</td>
#       <td id="T_d38fa_row3_col1" class="data row3 col1" >0.057328</td>
#       <td id="T_d38fa_row3_col2" class="data row3 col2" >0.207371</td>
#       <td id="T_d38fa_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d38fa_row3_col4" class="data row3 col4" >0.436783</td>
#       <td id="T_d38fa_row3_col5" class="data row3 col5" >0.392573</td>
#       <td id="T_d38fa_row3_col6" class="data row3 col6" >0.183928</td>
#       <td id="T_d38fa_row3_col7" class="data row3 col7" >-0.113970</td>
#     </tr>
#     <tr>
#       <th id="T_d38fa_level0_row4" class="row_heading level0 row4" >insulin</th>
#       <td id="T_d38fa_row4_col0" class="data row4 col0" >-0.073535</td>
#       <td id="T_d38fa_row4_col1" class="data row4 col1" >0.331357</td>
#       <td id="T_d38fa_row4_col2" class="data row4 col2" >0.088933</td>
#       <td id="T_d38fa_row4_col3" class="data row4 col3" >0.436783</td>
#       <td id="T_d38fa_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_d38fa_row4_col5" class="data row4 col5" >0.197859</td>
#       <td id="T_d38fa_row4_col6" class="data row4 col6" >0.185071</td>
#       <td id="T_d38fa_row4_col7" class="data row4 col7" >-0.042163</td>
#     </tr>
#     <tr>
#       <th id="T_d38fa_level0_row5" class="row_heading level0 row5" >bmi</th>
#       <td id="T_d38fa_row5_col0" class="data row5 col0" >0.017683</td>
#       <td id="T_d38fa_row5_col1" class="data row5 col1" >0.221071</td>
#       <td id="T_d38fa_row5_col2" class="data row5 col2" >0.281805</td>
#       <td id="T_d38fa_row5_col3" class="data row5 col3" >0.392573</td>
#       <td id="T_d38fa_row5_col4" class="data row5 col4" >0.197859</td>
#       <

# %% [markdown]
# ##División del conjunto de datos en entretamiento / test --> CV

# %% [markdown]
# ##Scikit-learn

# %%
# División Conjunto de Datos Entrenamiento / Test
# Controlamos la reproducibilidad en la división con random_state = 0
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.99,random_state=0)

# %%
#feature_cols = ['pregnant', 'glucose', 'bp' ,'skin','insulin', 'bmi','pedigree','age']

# %%
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression(penalty='none', random_state = 0, max_iter=200).fit(X_train,y_train)
modelo
print("Intercept:", modelo.intercept_)
print("Coeficiente:", modelo.coef_)
print("Precisión del modelo datos de entrenamiento (train):", modelo.score(X_train,y_train))
print("Precisión del modelo datos de validación (test):", modelo.score(X_test,y_test))
# Out:
# Intercept: [-0.01999544]
# Coeficiente: [[-0.19010773  0.80543405 -1.00003525 -0.14532435 -0.13139139 -0.14562215
#    0.01261109 -0.82169799]]
# Precisión del modelo datos de entrenamiento (train): 1.0
# Precisión del modelo datos de validación (test): 0.6675427069645203

# %%
scores = cross_val_score(modelo, X, y, scoring='accuracy', cv=10)
print(scores)
print('Precisión del modelo con CV: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# [0.72727273 0.76623377 0.80519481 0.72727273 0.75324675 0.75324675
#  0.80519481 0.80519481 0.75       0.82894737]
# Precisión del modelo con CV: 0.772 (0.034)

# %%
modelo
# Out:
# LogisticRegression(max_iter=200, penalty='none', random_state=0)

# %%
# Evaluación mediante validación cruzada
from numpy import mean
from numpy import std
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(penalty='none', random_state=0, max_iter=200)
scores = cross_val_score(model, X, y, scoring='accuracy', cv=7)
print(scores)
print('Precisión del modelo con CV: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# [0.75454545 0.8        0.71818182 0.79090909 0.76363636 0.81651376
#  0.77981651]
# Precisión del modelo con CV: 0.775 (0.030)

# %%
from sklearn import metrics
from matplotlib.pyplot import subplots, show

y_pred = modelo.predict(X_test)
cm = metrics.confusion_matrix(y_test, y_pred)
cm

fig, ax = subplots(figsize=(8, 8))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0, 1), ticklabels=('0s Estimados', '1s Estimados'))
ax.yaxis.set(ticks=(0, 1), ticklabels=('0s Actuales', '1s Actuales'))
ax.set_ylim(1.5, -0.5)
for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i, j], ha='center', va='center', color='red')
show()

# %%
# import required modules
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_pred_proba = modelo.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.plot([0, 1], [0, 1], 'k--', label = 'Random , auc=0.5')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ##Statsmodels

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Creación del modelo utilizando matrices como en scikitlearn
# ==============================================================================
# A la matriz de predictores se le tiene que añadir una columna de 1s para el intercept del modelo
X_train = sm.add_constant(X, prepend=True)
modelo2 = sm.Logit(endog=y, exog=X_train,)
modelo2 = modelo2.fit()
print(modelo2.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.470993
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  label   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      759
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 02 Jan 2023   Pseudo R-squ.:                  0.2718
# Time:                        20:13:58   Log-Likelihood:                -361.72
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 9.652e-54
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -8.4047      0.717    -11.728      0.000      -9.809      -7.000
# pregnant       0.1232      0.032      3.840      0.000       0.060       0.186
# glucose        0.0352      0.004      9.481      0.000       0.028       0.042
# bp            -0.0133      0.005     -2.540      0.011      -0.024      -0.003
# skin           0.0006      0.007      0.090      0.929      -0.013       0.014
# insulin       -0.0012      0.001     -1.322      0.186      -0.003       0.001
# bmi            0.0897      0.015      5.945      0.000       0.060       0.119
# pedigree       0.9452      0.299      3.160      0.002       0.359       1.531
# age            0.0149      0.009      1.593      0.111      -0.003       0.033
# ==============================================================================

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6, 3.84))

sns.violinplot(
        x     = 'label',
        y     = 'insulin',
        data  = datos,
        #color = "white",
        ax    = ax
    )

ax.set_title('Nivel insulina según diabetes');

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x="insulin", y="label",
            y_jitter = 0.03,
            data=datos,
            logistic=True,
            ci=None)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x="bmi", y="label",
            y_jitter = 0.03,
            data=datos,
            logistic=True,
            ci=None)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6, 3.84))

sns.violinplot(
        x     = 'label',
        y     = 'glucose',
        data  = datos,
        #color = "white",
        ax    = ax
    )

ax.set_title('Nivel glucosa según diabetes');

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x="glucose", y="label",
            y_jitter = 0.03,
            data=datos,
            logistic=True,
            ci=None)
plt.show()

# %% [markdown]
# ##Selección predictor insulin

# %%
# Adecuación de la matriz de datos de entrada
import pandas as pd
from numpy import array
X = array(datos['insulin']).reshape(-1,1)
y = array(datos['label'])

# %%
# División Conjunto de Datos Entrenamiento / Test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
# fit the model with data
modelo.fit(X_train,y_train)
# test the model
y_pred=modelo.predict(X_test)
modelo.score(X_test,y_test)
# Out:
# 0.6822916666666666

# %%
print("Intercept:", modelo.intercept_)
print("Coeficiente:", modelo.coef_)
print("Precisión del modelo:", modelo.score(X_test,y_test))
# Out:
# Intercept: [-0.79966585]
# Coeficiente: [[0.0024493]]
# Precisión del modelo: 0.6822916666666666

# %%
# fit the model with data
modelo.fit(X,y)
# test the model
y_pred=modelo.predict(X)
modelo.score(X,y)
# Out:
# 0.6575520833333334

# %%
# evaluate a logistic regression model using k-fold cross-validation
from numpy import mean, std, absolute, sqrt
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(penalty='none', random_state=0, max_iter=200)
scores = cross_val_score(model, X, y, scoring='accuracy', cv=10)
print(scores)
print('Precisión del modelo con CV (k=7): %.3f (%.3f)' % (mean(scores), std(scores)))
sqrt(mean(absolute(scores)))
# Out:
# [0.67532468 0.64935065 0.64935065 0.62337662 0.64935065 0.68831169
#  0.63636364 0.66233766 0.67105263 0.65789474]
# Precisión del modelo con CV (k=7): 0.656 (0.018)
# 0.8101057710069276

# %%
# evaluate a logistic regression model using leave-one-out
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from numpy import mean, std, absolute, sqrt
cv = LeaveOneOut()
model = LogisticRegression(penalty='none', random_state=0)
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Precisión del modelo con leave-one-out CV: %.3f (%.3f)' % (mean(scores), std(scores)))
sqrt(mean(absolute(scores)))
# Out:
# Precisión del modelo con leave-one-out CV: 0.656 (0.475)
# 0.8100925873009825

# %%
# import required modules
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_pred_proba = modelo.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.plot([0, 1], [0, 1], 'k--', label = 'Random , auc=0.5')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ##Selección predictor BMI

# %%
# Adecuación de la matriz de datos de entrada
import pandas as pd
from numpy import array
X = array(datos['bmi']).reshape(-1,1)
y = array(datos['label'])

# %%
# División Conjunto de Datos Entrenamiento / Test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
# fit the model with data
modelo.fit(X_train,y_train)
# test the model
y_pred=modelo.predict(X_test)
modelo.score(X_test,y_test)
# Out:
# 0.6875

# %%
# import required modules
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_pred_proba = modelo.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data, auc="+str(auc))
plt.plot([0, 1], [0, 1], 'k--', label = 'Random , auc=0.5')
plt.legend(loc=4)
plt.show()
